# %%
# while loop
while condition:
    #code block

# %%
# infinite loop
while True:
    print("Bappy")
# Out:
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# ...

# %%
i = 0
while i<10:
    print("Bappy")
    i += 1
# Out:
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy
# Bappy

# %%
# program to print multiplication table
num = int(input("Enter number: "))
i = 1
while i<11:
    print(num,"*",i,"=",num*i)
    i += 1
# Out:
# 4 * 1 = 4
# 4 * 2 = 8
# 4 * 3 = 12
# 4 * 4 = 16
# 4 * 5 = 20
# 4 * 6 = 24
# 4 * 7 = 28
# 4 * 8 = 32
# 4 * 9 = 36
# 4 * 10 = 40

# %%
# while lop with else
x = 1
while x<4:
    print(x)
    x += 1

else:
    print("Program Executed")
# Out:
# 1
# 2
# 3
# Program Executed
