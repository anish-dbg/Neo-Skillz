# %%
# Login function demo
# identation

"""
Email: anishkr01@gmail.com
Password: 1234
"""

email = input("Enter your email address: ")
password = input("Enter your password: ")

if email == "anishkr01@gmail.com" and password == "1234":
    print("login Successfull !")

elif email == "anishkr01@gmail.com" and password != "1234":
      print("Please try again")
      password = input("Enter the correct password again: ")

      if password == "1234":
         print("Success")
      else:
          print("wrong password")
else:
    print("Invalid credentials")
# Out:
# Invalid credentials

# %%
if condition:
    # write something (true)

elif:
    # write something

elif:
   # write something
else:
    # write something (false)

# %%
"""
Exercise -1
find the min number in 3 given numbers
"""
"""
num1 = int(input("Enter num1: "))
num2 = int(input("Enter num2: "))
num3 = int(input("Enter num3: "))

if num1<num2 and num1<num3:
    print("minimun number: ", num1)
elif num2<num1 and num2<num3:
    print("minimum number: ",num2)
else:
    print("minimum number: ",num3)

"""


"""
Exercise -2
ATM Machine menu

1. Pin change
2. balance check
3. withdraw
4. Deposit
5. Exit
"""

balAmount = 1000

menu = print("""
1. pin change
2. Balance Check
3. Withdraw
4. Deposit
5. Exit
""")

choice = int(input("Enter options: "))

if choice == 1:
    pinChange = int(input("Enter the pin: "))
    print("pin successfully changed")
elif choice == 2:
    print("Balance: ", balAmount)
elif choice == 3:
    amount = int(input("Enter the amount: "))
    if amount <= balAmount:
       balAmount -= amount
       print("Balance: ",balAmount)
    else: 
        print("insufficient balance")
elif choice == 4:
    amount = int(input("Enter the amount: "))
    balAmount += amount
    print("Balance: ",balAmount)
else :
    print("exit")
# Out:
# 1. pin change
# 2. Balance Check
# 3. Withdraw
# 4. Deposit
# 5. Exit
#
# pin successfully changed
