# %% [markdown]
# modules:
# - Modules is a single python file which is written by smart developers, th file contain function, methods, classes and variables. where as coders import it and use it in thier work.
#
# There are two types of python module
# - Built-in modules
# - external modules

# %% [markdown]
# Built-in modules is a modules which is  already available inside python

# %%
import sys

# get all built-in module names
built_in_modules = sys.builtin_module_names

print("Number of built-in modules:", len(built_in_modules))
# Out:
# Number of built-in modules: 69

# %%
import sys

print(sys.version)
# Out:
# 3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:09:58) [MSC v.1929 64 bit (AMD64)]

# %%
import math 

math.sqrt(25)
math.factorial(4)
# Out:
# 24

# %%
import keyword

print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
import random

print(random.randint(0,100))
# Out:
# 51

# %%
import datetime 
print(datetime.datetime.now())
# Out:
# 2026-06-29 16:36:20.136785

# %%
help("modules")
# Out:
# Please wait a moment while I gather a list of all available modules...
# Database not initialized by migration_upgrade(). Running it again
# c:\Users\hpw\anaconda3\Lib\site-packages\conda_pack\core.py:16: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# c:\Users\hpw\anaconda3\Lib\site-packages\nltk\twitter\__init__.py:20: UserWarning:
#
# The twython library has not been installed. Some functionality from the twitter package will not be available.
#
# c:\Users\hpw\anaconda3\Lib\pkgutil.py:78: UserWarning:
#
# The superqt.qtcompat module is deprecated as of v0.3.0. Please import from `qtpy` instead.
# IPython             calendar            markdown            shlex
# OpenSSL             cattr               markdown_it         shutil
# ...

# %% [markdown]
#  External modules is a module which is install from internet and does not present inside python

# %%
# pypi all package here
# !pip install fastapi
# Out:
# ...
#   Using cached annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# ...
# Using cached annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# ...
#
#    -------------------------- ------------- 2/3 [fastapi]
#    -------------------------- ------------- 2/3 [fastapi]
#    ---------------------------------------- 3/3 [fastapi]
#
# ...

# %%
# !pip uninstall fastapi
# pip list
# Out:
# ^C

# %%
from fastapi import FastAPI
from uvicorn import run as app_run

app = FastAPI()

@app.get("/")
async def root():
    return {"msg:" "Hello World"}

if __name__ == "__main__":
    app_run(app,host="0.0.0.0", port=8080)
