# %% [markdown]
# Pickling in python
#
# pickling
# - pickling is the process where by a python object hierarchy is converted into a byte stream, and unpickling is the inverse operation, whereby a byte stream (from a binary file or bytes-like object) is converted back into an object hierarchy
# - convert python object into a binary representation
# - used in machine learning ( store data in binary form)

# %%
def display_info():
    return "Hi my name is anish"

# %%
d = display_info()

# %%
# pickle dump
import pickle
with open('files/function.pkl','wb') as f:
    pickle.dump(d,f)

# %%
# pickle load
import pickle
with open('files/function.pkl','rb') as f:
    p = pickle.load(f)
    print(p)
# Out:
# Hi my name is anish
