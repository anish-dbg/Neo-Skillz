# %% [markdown]
# oops ( object oriented programming language)
# -A methodology which is used to clarify and write clean, structured code, and efficiently manage the codebase.

# %% [markdown]
# Class Vs Object

# %%
l = [1,2,3,4,5]
l.uuper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 2
#       1 l = [1,2,3,4,5]
# ----> 2 l.uuper()
#
# AttributeError: 'list' object has no attribute 'uuper'

# %%
s = 'anish'
s.append('f')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 2
#       1 s = 'anish'
# ----> 2 s.append('f')
#
# AttributeError: 'str' object has no attribute 'append'

# %%
a = 66
a[0] = 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 a = 66
# ----> 2 a[0] = 1
#
# TypeError: 'int' object does not support item assignment

# %%
print(type(l))
# Out:
# <class 'list'>

# %%
print(type(s))  # in python whatever the data-type using it's  class
# Out:
# <class 'str'>

# %%
L = list()
S = str()

# %% [markdown]
# whatever the data-type using in the python is class and to store this particular class in a variable is known as object ( instance of class)

# %% [markdown]
# whatever the thing written in the class we can access through object

# %% [markdown]
# - samsung = mobile()
# - iphone = mobile()
# - motorola = mobile()
# - nothing = mobile()
#
#
# - toyota = car()
# - bmw = car()
# - mercedes = car()
# - hyundai = car()
# - maruti_suzuki = car()

# %%
# object_name = class_name()

# %% [markdown]
# A class is a blueprint that defines the properties and behaviors of its objects (or instances)
