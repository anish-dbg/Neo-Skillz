# %% [markdown]
# Magic Methods/Dunder Methods in OOp

# %%
# __methodname__() = magic method ( it's automatically execute)

# %%
class Temp:
    def __anish__(self):
        print("Hello world!")

# %%
obj = Temp()

# %% [markdown]
# Concept of self in OOP

# %%
# self - pointing the same calss
