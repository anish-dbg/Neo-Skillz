# %% [markdown]
# Collection of class objects in OOP

# %%
class Person:
    def __init__(self, name, country):
        self.name = name
        self.country = country

# %%
p1 = Person("Bappy", "UK")
p2 = Person("Alex", "USA")
p3 = Person("Anish", "India")

# %%
l = [p1,p2,p3]
print(l)
# Out:
# [<__main__.Person object at 0x000001BA6DC386E0>, <__main__.Person object at 0x000001BA6DCFD6D0>, <__main__.Person object at 0x000001BA6DCFE850>]

# %%
for i in l:
    print(i.name, i.country)
# Out:
# Bappy UK
# Alex USA
# Anish India

# %%
l1 = (p1,p2,p3)
print(l1)
# Out:
# (<__main__.Person object at 0x000001BA6DC386E0>, <__main__.Person object at 0x000001BA6DCFD6D0>, <__main__.Person object at 0x000001BA6DCFE850>)

# %%
for i in l1:
    print(i.name, i.country)
# Out:
# Bappy UK
# Alex USA
# Anish India

# %% [markdown]
# Static Variables & Methods in OOP

# %%
class AtmMachine:
    # Constructor ( special function) -> superpowers
    # self means it's a function of AtmMachine

    # static variable : define the variable inside the class not in constructor
    __customer_id = 0
    def __init__(self):
        # data property
        print(id(self))
        self.pin = ""
        self.__balance = 0 # private variable
        self.customer_id = AtmMachine.__customer_id
        AtmMachine.__customer_id += 1
      #  self.menu()

    @staticmethod
    def get_customer_id():
        return AtmMachine.__customer_id

    # sett




# getter method : it return the private property
    def get_balance(self):
        return self.__balance

    # setter method: it sets the value in the private property
    def set_balance(self,new_balance):
        if type(new_balance) == int:
            self.__balance = new_balance
        else:
            print("error")



    def menu(self):
        user_input = input(
        """
        Hi how can i help you ?

        1. Press 1 to create pin
        2. Press 2 to change pin
        3. Press 3 to check balance
        4. Press 4 to withdraw
        5. Anything to exit
        """
        )

        if user_input == "1":
            #create a pin
            self.create_pin()
        elif user_input == "2":
            #change pin
            self.change_pin()
        elif user_input == "3":
            #check balance 
            self.check_balance()
        elif user_input == "4":
            #change withdraw
           # pass
           self.withdraw_balance()

        else:
            exit()
    def create_pin(self):   # putting argument as a self in the function that means it's a function of the class
        user_pin = input("Enter your pain: ")
        self.pin = user_pin

        user_balance = int(input("Enter Balance: "))
        self.__balance = user_balance

        print("Pin Created Successfully!")
    #    self.menu()  # it's a converstion between two methods

    
    def change_pin(self):
        old_pin = input("Enter your old pin: ")

        if old_pin == self.pin:
            new_pin = input("Enter new pin: ")
            self.pin = new_pin
            print("Pin changed successfully!")
         #   self.menu()
        else:
            print("Invalid pin!")
          #  self.menu()
            
    def check_balance(self):
        user_pin = input("Enter your pin: ")
        if user_pin == self.pin:
            print(f"Your balance is {self.__balance}")
        else:
            print("Your pin is incorrect, please try again")
       # self.menu()

    def withdraw_balance(self):
        user_pin = input("Enter the pin: ")
        if user_pin == self.pin:
            # allow to withdraw
            amount = int(input("Enter the amount : "))
            if amount <= self.__balance:
                self.__balance -= amount
                print(f"You have withdraw {amount}. your new balance is {self.__balance}")
            else:
                print("Insufficient balance!")
        else:
            print("Your pin is incorrect, please try again")
       # self.menu()

# %%
c1 = AtmMachine()
# Out:
# 1809680729152

# %%
AtmMachine.get_customer_id()
# Out:
# 1

# %%
AtmMachine.__customer_id
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 AtmMachine.__customer_id
#
# AttributeError: type object 'AtmMachine' has no attribute '__customer_id'

# %%
c2 = AtmMachine()
# Out:
# 1900217882960

# %%
AtmMachine.customer_id
# Out:
# 2
