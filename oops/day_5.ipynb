# %% [markdown]
# Reference Variable
# - it is refernce to the same object

# %%
class Person:
    def __init__(self):
        self.name = "Anish"
        self.country = "india"

# %%
p = Person()

# %%
id(p)
# Out:
# 2211452192816

# %%
q = p
id(q)
# Out:
# 2211452192816

# %%
print(p.name)
print(q.name)
# Out:
# Anish
# Anish

# %%
q.name = 'Alex'

# %%
print(p.name)
print(q.name)
# Out:
# Alex
# Alex

# %% [markdown]
# Pass by reference in OOP

# %%
class Person:

    def __init__(self,name,gender):
        self.name = name
        self.gender = gender


# outside the class
def greeting(person):
    print(f"Hi my name is {person.name} and i am a {person.gender}")
    p1 = Person("Alex","Male")  # initializing the class object
    return p1

# %%
p = Person("Anish","male")

# %%
a = greeting(p)
# Out:
# Hi my name is Anish and i am a male

# %%
a.name
# Out:
# 'Alex'

# %%
a.gender
# Out:
# 'Male'

# %%
class Person1:

    def __init__(self,name,gender):
        self.name = name
        self.gender = gender

# outside of the class
def greeting(person):
    person.name = 'Alex'
    return person

# %%
p = Person1('Anish','male')

# %%
print(id(p))
# Out:
# 2211453406912

# %%
a1 = greeting(p)

# %%
a1.name
# Out:
# 'Alex'

# %%
print(id(a1))
# Out:
# 2211453406912

# %%
# class multable
