# %% [markdown]
# Virtual env create:
# - conda create -n project1 python=(versions) -y
# - conda activate project1
# - pip list
# - pip install pandas==
# - conda deactivate
# - conda env list
# - conda activate base
