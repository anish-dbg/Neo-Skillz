# %% [markdown]
# Implicit
#  - Internally by Python
#
# Explicit
# - By the Programmers

# %%
# Implicit

print(5 + 5.5)
# Out:
# 10.5

# %%
# Explicit
print(3 + int("4"))
# Out:
# 7

# %%
num = "34"
num = int(num)
type(num)
# Out:
# int

# %%
num = "34"
num = float(num)
type(num)
print(num)
# Out:
# 34.0

# %%
num = 4+6j
type(num)
# Out:
# complex

# %%
int(num)

# we cant convert complex number to int and float
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 int(num)
#       3 # we cant convert complex number to int and float
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
str(num)
# Out:
# '(4+6j)'
