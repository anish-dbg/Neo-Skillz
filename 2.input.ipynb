# %% [markdown]
# Static Content:
# - Calender and Clock widgets that display fixed or locally-generated information.
# Dynamic Content:
# - YouTube and Facebook widgets that fetch real-time data from external sources.

# %% [markdown]
# input()
# - used to take input from user
# - by default this input function convert all the data into string

# %%
var = input("Enter anything: ")
print(var)
# Out:
# Hey! how are you?

# %%
type(var)
# Out:
# str
