# %% [markdown]
# Common Functions/Methods
# - len
# - max
# - min
# - sorted

# %%
s = "Welcome to python"
len(s)
# Out:
# 17

# %%
max(s) # max character -- Ascii
# Out:
# 'y'

# %%
min(s)
# Out:
# ' '

# %%
sorted(s)
# Out:
# [' ',
#  ' ',
#  'W',
#  'c',
#  'e',
#  'e',
#  'h',
#  'l',
#  'm',
#  'n',
#  'o',
#  'o',
#  'o',
#  'p',
#  't',
#  't',
#  'y']

# %%
s = "hello world"
sorted(s, reverse=True)
# Out:
# ['w', 'r', 'o', 'o', 'l', 'l', 'l', 'h', 'e', 'd', ' ']

# %% [markdown]
# Strings Functions/Methods
# - Capitalize
# - Title
# - Upper
# - Lower
# - Swapcase

# %%
s = "welcome to python"
s.capitalize()  # first index of string becomes capital
# Out:
# 'Welcome to python'

# %%
print(s)
# Out:
# welcome to python

# %%
s.title()   # individual starting string make the first index is upper
# Out:
# 'Welcome To Python'

# %%
s.upper()
# Out:
# 'WELCOME TO PYTHON'

# %%
s.lower()
# Out:
# 'welcome to python'

# %%
s = 'EwlCoMe'
s.swapcase()  # swap small char becomes uppercase,where uppercase becomes lowercase
# Out:
# 'eWLcOmE'

# %% [markdown]
# - count
# - find
# - index

# %%
s = "My name is Bappy"
s.count("n")
# Out:
# 1

# %%
s.find("a")
# Out:
# 4

# %%
s.find("z")
# Out:
# -1

# %%
s.index("z")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 s.index("z")
#
# ValueError: substring not found

# %%
s = "My name is Bappy"
s.endswith("py")    # web scrapping
# Out:
# True

# %%
s.startswith("My")
# Out:
# True

# %%
# format
name = "Bappy"
gender = "Male"

s = "My name is {}, and I am a {}"
s.format(name,gender)
# Out:
# 'My name is Bappy, and I am a Male'

# %%
s = "Welcome {} to facebook"
name = "Anish"
s.format(name)
# Out:
# 'Welcome Anish to facebook'

# %%
name = "Bappy"
gender = "Male"

s = "My name is {1}, and I am a {0}"
s.format(gender,name)
# Out:
# 'My name is Bappy, and I am a Male'

# %% [markdown]
# - isalnum
# - isalpha
# - isdigit
# - isidentifier

# %%
s = "Bappy123"
s.isalnum()
# Out:
# True

# %%
s = "Bappy"
s.isalpha()
# Out:
# True

# %%
s = "123"
s.isdigit()
# Out:
# True

# %%
s = '_name'
s = '1name'
s.isidentifier()
# Out:
# False

# %%
# split
s = "my,name,is,Bappy"
s.split(",")
#print(type(a))
# Out:
# ['my', 'name', 'is', 'Bappy']

# %%
words = ['My', 'name', 'is', 'Bappy']
s = "-"
s = s.join(words)
print(s)
# Out:
# My-name-is-Bappy

# %%
# replace
s = "My name is Bappy"
s.replace("Bappy", "Alex")
# Out:
# 'My name is Alex'

# %%
# strip
s = " My name is Bappy      "
#s.strip()
print(s)
print(len(s))
s.strip() # remove unwanted spaces and specific chars
print(len(s))
# Out:
#  My name is Bappy
# 23
# 23

# %%
# f-strings
name = "Bappy"
gender = "Male"

s= f"My name is {name}. I am a {gender}"
print(s)
# Out:
# My name is Bappy. I am a Male
